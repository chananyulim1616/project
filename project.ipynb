# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

import numpy as np
import pandas as pd
from datetime import datetime
df = pd.read_csv('bsc tx.csv')
df2 = pd.read_csv('bsc price.csv')
df3 = pd.read_csv('eth tx.csv')
df4 = pd.read_csv('eth price.csv')
df5 = pd.read_csv('bnb tx2.csv')
df6 = pd.read_csv('bnb price2.csv')
for x in range(len(df)):
    df['Date'][x] = datetime.strptime(df['Date'][x], '%m/%d/%Y',)
for x in range(len(df3)):
    df3['Date'][x] = datetime.strptime(df3['Date'][x], '%m/%d/%Y',)
for x in range(len(df2)):
    df2['Date'][x] = datetime.strptime(df2['Date'][x], '%m/%d/%Y',)
for x in range(len(df4)):
    df4['Date'][x] = datetime.strptime(df4['Date'][x], '%m/%d/%Y',)
for x in range(len(df5)):
    df5['Date'][x] = datetime.strptime(df5['Date'][x], '%m/%d/%Y',)
for x in range(len(df6)):
    df6['Date'][x] = datetime.strptime(df6['Date'][x], '%b %d, %Y',)#Nov 18, 2021
print(df4.to_string())
# Out:
# C:\Users\CHANAN~1\AppData\Local\Temp/ipykernel_16828/2065719287.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'][x] = datetime.strptime(df['Date'][x], '%m/%d/%Y',)
# C:\Users\CHANAN~1\AppData\Local\Temp/ipykernel_16828/2065719287.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Date'][x] = datetime.strptime(df3['Date'][x], '%m/%d/%Y',)
# C:\Users\CHANAN~1\AppData\Local\Temp/ipykernel_16828/2065719287.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
start = '10/11/2020'
start= datetime.strptime(start ,'%d/%m/%Y')
print(type(start))
print(start)
# Out:
# <class 'datetime.datetime'>
# 2020-11-10 00:00:00

# %%
x1=[]
x3=[]
y1=[]
y3=[]
x5=[]
y5=[]
for x in range(len(df)):
     if df['Date'][x] >= start:
          x1.append(df['Date'][x].strftime('%Y-%m-%d'))
          y1.append(df['Value'][x])
for x in range(len(df3)):
     if df3['Date'][x] >= start:
          x3.append(df3['Date'][x].strftime('%Y-%m-%d'))
          y3.append(df3['Value'][x])
for x in range(len(df5)):
     if df5['Date'][x] >= start:
          x5.append(df5['Date'][x].strftime('%Y-%m-%d'))
          y5.append(df5['Value'][x])

# %%
#print(len(x1))
#print(len(y1))
#print(y1)

# %%
plt.plot(x1, y1)

# %%
#print(df2['Price'].to_string())

# %%
x2=[]
x4=[]
y2=[]
y4=[]
x6=[]
y6=[]

for x in range(len(df2)):
     #print(df['Date'][x])
     if df2['Date'][x] >= start:
          x2.append(df2['Date'][x].strftime('%Y-%m-%d'))
          y2.append(df2['Price'][x])

for x in range(len(df4)):
     if df4['Date'][x] >= start:
          x4.append(df4['Date'][x].strftime('%Y-%m-%d'))
          y4.append(df4['Price'][x])
for x in range(len(df6)):
     if df6['Date'][x] >= start:
          x6.append(df6['Date'][x].strftime('%Y-%m-%d'))
          y6.append(df6['Price'][x])

# %%
#x6y6
x6n=[]
y6n=[]
#print(range(len(df6)))
#x5 y5 ไม่มีวันที่ 18
for x in range(len(df6)):
    if x!=373 :
        x6n.append(x6[-(x+1)])
for x in range(len(df6)):
    if x!=373 :
        y6n.append(y6[-(x+1)])
print(len(x6n))
# Out:
# 373

# %%
plt.plot(x1, y1)

# %%
plt.plot(x4, y4)

# %%
fig, ax = plt.subplots()
fig.subplots_adjust(right=0.75)

twin1 = ax.twinx()
#twin2 = ax.twinx()

# Offset the right spine of twin2.  The ticks and label have already been
# placed on the right by twinx above.
#twin2.spines.right.set_position(("axes", 1.2))

p1, = ax.plot([0, 1, 2], [0, 1, 2], "b-", label="Density")
p2, = twin1.plot([0, 1, 2], [0, 3, 2], "r-", label="Temperature")
#p3, = twin2.plot([0, 1, 2], [50, 30, 15], "g-", label="Velocity")

ax.set_xlim(0, 2)
ax.set_ylim(0, 2)
twin1.set_ylim(0, 4)
#twin2.set_ylim(1, 65)

ax.set_xlabel("Distance")
ax.set_ylabel("Density")
twin1.set_ylabel("Temperature")
#twin2.set_ylabel("Velocity")

ax.yaxis.label.set_color(p1.get_color())
twin1.yaxis.label.set_color(p2.get_color())
#twin2.yaxis.label.set_color(p3.get_color())

tkw = dict(size=4, width=1.5)
ax.tick_params(axis='y', colors=p1.get_color(), **tkw)
twin1.tick_params(axis='y', colors=p2.get_color(), **tkw)
#twin2.tick_params(axis='y', colors=p3.get_color(), **tkw)
ax.tick_params(axis='x', **tkw)

ax.legend(handles=[p1, p2,])

plt.show()

# %%
x = [datetime.strptime(d,'%Y-%m-%d').date() for d in x4]
fig, ax = plt.subplots()
fig.subplots_adjust(right=0.75)

twin1 = ax.twinx()
p1, = ax.plot(x, y3, "b-", label="Transaction")
p2, = twin1.plot(x, y4, "r-", label="Price")
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m/%d/%Y'))
#plt.gca().xaxis.set_major_locator(mdates.DayLocator())

#ax.set_xlim(0, 2)
#ax.set_ylim(0, 2)
#twin1.set_ylim(0, 4)

ax.set_xlabel("Date")
ax.set_ylabel("Transaction")
twin1.set_ylabel("Price")
#ข้อแกน x y

ax.yaxis.label.set_color(p1.get_color())
twin1.yaxis.label.set_color(p2.get_color())
#สีตัวอักษร

tkw = dict(size=5, width=1.5)
#size ขีดตรงแกน
ax.tick_params(axis='y', colors=p1.get_color(), **tkw)
twin1.tick_params(axis='y', colors=p2.get_color(), **tkw)

ax.tick_params(axis='x', **tkw)

ax.legend(handles=[p1, p2])
plt.gcf().autofmt_xdate()

# %%
def graph(a,b,c,d):

    x = [datetime.strptime(k,'%Y-%m-%d').date() for k in a]
    fig, ax = plt.subplots()
    fig.subplots_adjust(right=0.75)

    twin1 = ax.twinx()
    p1, = ax.plot(x, b, "b-", label="Transaction")
    p2, = twin1.plot(x, d, "r-", label="Price")
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m/%d/%Y'))
#plt.gca().xaxis.set_major_locator(mdates.DayLocator())

#ax.set_xlim(0, 2)
#ax.set_ylim(0, 2)
#twin1.set_ylim(0, 4)

    ax.set_xlabel("Date")
    ax.set_ylabel("Transaction")
    twin1.set_ylabel("Price")
#ข้อแกน x y

    ax.yaxis.label.set_color(p1.get_color())
    twin1.yaxis.label.set_color(p2.get_color())
#สีตัวอักษร

    tkw = dict(size=5, width=1.5)
#size ขีดตรงแกน
    ax.tick_params(axis='y', colors=p1.get_color(), **tkw)
    twin1.tick_params(axis='y', colors=p2.get_color(), **tkw)

    ax.tick_params(axis='x', **tkw)

    ax.legend(handles=[p1, p2])
    plt.gcf().autofmt_xdate()

# %%
graph(x1,y1,x2,y2)
graph(x3,y3,x4,y4)
graph(x1,y1,x3,y3)
#tx
graph(x2,y2,x4,y4)

# %%
#print(x5[-1])
#print(x6n[-1])
graph(x5,y5,x6n,y6n)

# %%
import datetime as dt

dates = ['01/02/1991','01/03/1991','01/04/1991']
x = [dt.datetime.strptime(d,'%m/%d/%Y').date() for d in dates]
y = range(len(x)) # many thanks to Kyss Tao for setting me straight here

import matplotlib.pyplot as plt
import matplotlib.dates as mdates

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m/%d/%Y'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator())
plt.plot(x,y)
plt.gcf().autofmt_xdate()

# %%
x = [datetime.strptime(k,'%Y-%m-%d').date() for k in x5[220:-1]]
fig, ax = plt.subplots()
fig.subplots_adjust(right=0.75)

twin1 = ax.twinx()
p1, = ax.plot(x, y5[220:-1], "b-", label="Transaction")
p2, = twin1.plot(x, y6n[220:-1], "r-", label="Price")
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m/%d/%Y'))
#plt.gca().xaxis.set_major_locator(mdates.DayLocator())

ax.set_xlabel("Date")
ax.set_ylabel("Transaction")
twin1.set_ylabel("Price")
#ข้อแกน x y

ax.yaxis.label.set_color(p1.get_color())
twin1.yaxis.label.set_color(p2.get_color())
#สีตัวอักษร

tkw = dict(size=5, width=1.5)
#size ขีดตรงแกน
ax.tick_params(axis='y', colors=p1.get_color(), **tkw)
twin1.tick_params(axis='y', colors=p2.get_color(), **tkw)

ax.tick_params(axis='x', **tkw)

ax.legend(handles=[p1, p2])
plt.gcf().autofmt_xdate()
